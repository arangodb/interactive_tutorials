# %%
# %%capture
# !git clone https://github.com/arangodb/interactive_tutorials.git
# !rsync -av interactive_tutorials/notebooks/data  interactive_tutorials/notebooks/img  interactive_tutorials/notebooks/tools ./ --exclude=.git
# !pip install python-arango
# !pip install arangopipe==0.0.6.9.5
# !pip install pandas PyYAML==5.1.1 sklearn2
# !pip install jsonpickle
# !pip3 install networkx
# !pip3 install matplotlib
# !pip3 install adbnx-adapter

# %%
login = {"hostname": "arangoml.arangodb.cloud",\
         "username": "MLathah4gprchmhtlbrostz8",\
         "dbName": "MLqugvfcgt448hq4bpqccnw",\
         "password": "ML34q4j114ha31n1j07c3ya9",\
         "port": 8529}

# %%
login
# Out:
# {'hostname': 'arangoml.arangodb.cloud',
#  'username': 'MLathah4gprchmhtlbrostz8',
#  'dbName': 'MLqugvfcgt448hq4bpqccnw',
#  'password': 'ML34q4j114ha31n1j07c3ya9',
#  'port': 8529}

# %%
# !chmod -R 755 ./tools/*

# %%
# Restore an ArangoDB dump into the database.
# !./tools/arangorestore  -c none --server.endpoint http+ssl://{login["hostname"]}:{login["port"]} --server.username {login["username"]} \
--server.database {login["dbName"]} \
--server.password {login["password"]} \
--replication-factor 3  \
--input-directory "data/retail_freq_cust_data_dump"
# Out:
# 2021-06-03T08:03:46Z [103169] INFO [05c30] {restore} Connected to ArangoDB 'http+ssl://arangoml.arangodb.cloud:8529'
# 2021-06-03T08:03:48Z [103169] INFO [abeb4] {restore} Database name in source dump is 'MLqugvfcgt448hq4bpqccnw'
# 2021-06-03T08:03:48Z [103169] INFO [9b414] {restore} # Re-creating document collection 'Customers'...
# 2021-06-03T08:03:49Z [103169] INFO [9b414] {restore} # Re-creating document collection 'datasets'...
# 2021-06-03T08:03:50Z [103169] INFO [9b414] {restore} # Re-creating document collection 'deployment'...
# 2021-06-03T08:03:52Z [103169] INFO [9b414] {restore} # Re-creating document collection 'devperf'...
# 2021-06-03T08:03:53Z [103169] INFO [9b414] {restore} # Re-creating document collection 'featuresets'...
# 2021-06-03T08:03:54Z [103169] INFO [9b414] {restore} # Re-creating document collection 'Items'...
# 2021-06-03T08:03:55Z [103169] INFO [9b414] {restore} # Re-creating document collection 'modelparams'...
# 2021-06-03T08:03:56Z [103169] INFO [9b414] {restore} # Re-creating document collection 'models'...
# 2021-06-03T08:03:57Z [103169] INFO [9b414] {restore} # Re-creating document collection 'project'...
# 2021-06-03T08:03:58Z [103169] INFO [9b414] {restore} # Re-creating document collection 'run'...
# 2021-06-03T08:03:59Z [103169] INFO [9b414] {restore} # Re-creating document collection 'servingperf'...
# 2021-06-03T08:04:01Z [103169] INFO [9b414] {restore} # Re-creating edge collection 'deployment_featureset'...
# 2021-06-03T08:04:02Z [103169] INFO [9b414] {restore} # Re-creating edge collection 'deployment_model'...
# 2021-06-03T08:04:03Z [103169] INFO [9b414] {restore} # Re-creating edge collection 'deployment_modelparams'...
# 2021-06-03T08:04:04Z [103169] INFO [9b414] {restore} # Re-creating edge collection 'deployment_servingperf'...
# 2021-06-03T08:04:05Z [103169] INFO [9b414] {restore} # Re-creating edge collection 'featureset_dataset'...
# 2021-06-03T08:04:06Z [103169] INFO [9b414] {restore} # Re-creating edge collection 'project_models'...
# 2021-06-03T08:04:07Z [103169] INFO [9b414] {restore} # Re-creating edge collection 'Purchases'...
# 2021-06-03T08:04:08Z [103169] INFO [9b414] {restore} # Re-creating edge collection 'run_datasets'...
# 2021-06-03T08:04:09Z [103169] INFO [9b414] {restore} # Re-creating edge collection 'run_devperf'...
# 2021-06-03T08:04:10Z [103169] INFO [9b414] {restore} # Re-creating edge collection 'run_featuresets'...
# 2021-06-03T08:04:11Z [103169] INFO [9b414] {restore} # Re-creating edge collection 'run_modelparams'...
# 2021-06-03T08:04:13Z [103169] INFO [9b414] {restore} # Re-creating edge collection 'run_models'...
# 2021-06-03T08:04:14Z [103169] INFO [6d69f] {restore} # Dispatched 23 job(s), using 2 worker(s)
# 2021-06-03T08:04:14Z [103169] INFO [94913] {restore} # Loading data into document collection 'Customers', data size: 4402 byte(s)
# 2021-06-03T08:04:14Z [103169] INFO [94913] {restore} # Loading data into document collection 'datasets', data size: 210 byte(s)
# 2021-06-03T08:04:15Z [103169] INFO [6ae09] {restore} # Successfully restored document collection 'datasets'
# 2021-06-03T08:04:15Z [103169] INFO [94913] {restore} # Loading data into document collection 'deployment', data size: 20 byte(s)
# 2021-06-03T08:04:15Z [103169] INFO [6ae09] {restore} # Successfully restored document collection 'deployment'
# 2021-06-03T08:04:15Z [103169] INFO [94913] {restore} # Loading data into document collection 'devperf', data size: 581 byte(s)
# 2021-06-03T08:04:15Z [103169] INFO [6ae09] {restore} # Successfully restored document collection 'Customers'
# 2021-06-03T08:04:15Z [103169] INFO [94913] {restore} # Loading data into document collection 'featuresets', data size: 224 byte(s)
# 2021-06-03T08:04:15Z [103169] INFO [6ae09] {restore} # Successfully restored document collection 'devperf'
# 2021-06-03T08:04:15Z [103169] INFO [94913] {restore} # Loading data into document collection 'Items', data size: 830 byte(s)
# 2021-06-03T08:04:15Z [103169] INFO [6ae09] {restore} # Successfully restored document collection 'featuresets'
# 2021-06-03T08:04:15Z [103169] INFO [6ae09] {restore} # Successfully restored document collection 'Items'
# 2021-06-03T08:04:15Z [103169] INFO [94913] {restore} # Loading data into document collection 'modelparams', data size: 261 byte(s)
# 2021-06-03T08:04:15Z [103169] INFO [94913] {restore} # Loading data into document collection 'models', data size: 266 byte(s)
# 2021-06-03T08:04:15Z [103169] INFO [6ae09] {restore} # Successfully restored document collection 'modelparams'
# 2021-06-03T08:04:15Z [103169] INFO [6ae09] {restore} # Successfully restored document collection 'models'
# 2021-06-03T08:04:15Z [103169] INFO [94913] {restore} # Loading data into document collection 'project', data size: 125 byte(s)
# 2021-06-03T08:04:15Z [103169] INFO [94913] {restore} # Loading data into document collection 'run', data size: 276 byte(s)
# 2021-06-03T08:04:16Z [103169] INFO [6ae09] {restore} # Successfully restored document collection 'project'
# 2021-06-03T08:04:16Z [103169] INFO [6ae09] {restore} # Successfully restored document collection 'run'
# 2021-06-03T08:04:16Z [103169] INFO [94913] {restore} # Loading data into document collection 'servingperf', data size: 20 byte(s)
# 2021-06-03T08:04:16Z [103169] INFO [94913] {restore} # Loading data into edge collection 'deployment_featureset', data size: 20 byte(s)
# 2021-06-03T08:04:16Z [103169] INFO [6ae09] {restore} # Successfully restored edge collection 'deployment_featureset'
# 2021-06-03T08:04:16Z [103169] INFO [6ae09] {restore} # Successfully restored document collection 'servingperf'
# 2021-06-03T08:04:16Z [103169] INFO [94913] {restore} # Loading data into edge collection 'deployment_model', data size: 20 byte(s)
# 2021-06-03T08:04:16Z [103169] INFO [94913] {restore} # Loading data into edge collection 'deployment_modelparams', data size: 20 byte(s)
# 2021-06-03T08:04:16Z [103169] INFO [6ae09] {restore} # Successfully restored edge collection 'deployment_model'
# 2021-06-03T08:04:16Z [103169] INFO [6ae09] {restore} # Successfully restored edge collection 'deployment_modelparams'
# 2021-06-03T08:04:16Z [103169] INFO [94913] {restore} # Loading data into edge collection 'deployment_servingperf', data size: 20 byte(s)
# 2021-06-03T08:04:16Z [103169] INFO [94913] {restore} # Loading data into edge collection 'featureset_dataset', data size: 128 byte(s)
# 2021-06-03T08:04:16Z [103169] INFO [6ae09] {restore} # Successfully restored edge collection 'deployment_servingperf'
# 2021-06-03T08:04:16Z [103169] INFO [94913] {restore} # Loading data into edge collection 'project_models', data size: 176 byte(s)
# 2021-06-03T08:04:16Z [103169] INFO [6ae09] {restore} # Successfully restored edge collection 'featureset_dataset'
# 2021-06-03T08:04:16Z [103169] INFO [6ae09] {restore} # Successfully restored edge collection 'project_models'
# 2021-06-03T08:04:16Z [103169] INFO [94913] {restore} # Loading data into edge collection 'Purchases', data size: 75415 byte(s)
# 2021-06-03T08:04:16Z [103169] INFO [94913] {restore} # Loading data into edge collection 'run_datasets', data size: 237 byte(s)
# 2021-06-03T08:04:16Z [103169] INFO [6ae09] {restore} # Successfully restored edge collection 'run_datasets'
# 2021-06-03T08:04:16Z [103169] INFO [94913] {restore} # Loading data into edge collection 'run_devperf', data size: 255 byte(s)
# 2021-06-03T08:04:16Z [103169] INFO [6ae09] {restore} # Successfully restored edge collection 'run_devperf'
# 2021-06-03T08:04:16Z [103169] INFO [94913] {restore} # Loading data into edge collection 'run_featuresets', data size: 245 byte(s)
# 2021-06-03T08:04:16Z [103169] INFO [6ae09] {restore} # Successfully restored edge collection 'run_featuresets'
# 2021-06-03T08:04:16Z [103169] INFO [94913] {restore} # Loading data into edge collection 'run_modelparams', data size: 260 byte(s)
# 2021-06-03T08:04:17Z [103169] INFO [6ae09] {restore} # Successfully restored edge collection 'run_modelparams'
# 2021-06-03T08:04:17Z [103169] INFO [94913] {restore} # Loading data into edge collection 'run_models', data size: 261 byte(s)
# 2021-06-03T08:04:17Z [103169] INFO [6ae09] {restore} # Successfully restored edge collection 'run_models'
# 2021-06-03T08:04:18Z [103169] INFO [6ae09] {restore} # Successfully restored edge collection 'Purchases'
# 2021-06-03T08:04:18Z [103169] INFO [a66e1] {restore} Processed 23 collection(s) in 32.994928 s, read 741115 byte(s) from datafiles, sent 17 data batch(es) of 741098 byte(s) total size

# %%
import networkx as nx
from adbnx_adapter.arangoDB_networkx_adapter import ArangoDB_Networkx_Adapter

# Specify the connection to the ArangoDB Database
con = {'dbName': login["dbName"],
 'username': login["username"],
 'password': login["password"],
 'hostname': login["hostname"],
 'port': login["port"]}

# Create Adapter instance
ma = ArangoDB_Networkx_Adapter(conn = con)

freq_customers = {'vertexCollections': {'Customers': {},
                                         'Items': {}},
                   'edgeCollections': {'Purchases': {'_from', '_to', 'spend'}}}

# Export networkX graph                                  
g = ma.create_networkx_graph(graph_name = '',  graph_attributes = freq_customers)

# %%
gp = g.to_undirected()

# %%
gp.number_of_edges()
# Out:
# 4475

# %%
cust_nodes = [n for n in gp.nodes() if n.startswith("Customers")]
item_nodes = [n for n in gp.nodes() if n.startswith("Items")]

# %%
len(cust_nodes)
# Out:
# 447

# %%
len(item_nodes)
# Out:
# 75

# %%
import networkx as nx
B = nx.Graph()
B.add_nodes_from(cust_nodes, bipartite=0)
B.add_nodes_from(item_nodes, bipartite=1)
B.add_edges_from(list(g.edges()))

# %%
from networkx.algorithms import bipartite
bipartite.is_bipartite(B)
# Out:
# True

# %%
nx.is_connected(B)
# Out:
# False

# %%
degc, degi = bipartite.degrees(B, item_nodes)

# %%
dc = [v for k,v in degc]
di = [v for k,v in degi]

# %%
import numpy as np
u, c = np.unique(dc, return_counts=True)
u = u[1:]
c = c[1:]
dv = u
fd = [d/sum(c) for d in c]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(rc={'figure.figsize':(11.7,8.27)})
ax = sns.scatterplot(u, fd)
plt.title("degree vs proportion ")
#plt.xlabel("Useregree")
# Out:
# Text(0.5, 1.0, 'degree vs proportion ')

# %%
import seaborn as sns
sns.set(rc={'figure.figsize':(11.7,8.27)})
ax = sns.distplot(dc, hist = True)
plt.title("Distribution of Customer Degree ")
plt.xlabel("Customer Degree")
# Out:
# Text(0.5, 0, 'Customer Degree')

# %%
sns.set(rc={'figure.figsize':(11.7,8.27)})
ax = sns.distplot(di, hist = True)
plt.title("Distribution of Item Degree ")
plt.xlabel("Item Degree")
# Out:
# Text(0.5, 0, 'Item Degree')

# %%
sns.set(rc={'figure.figsize':(11.7,8.27)})
ax = sns.distplot(di, hist = False)
plt.title("Distribution of Item Degree ")
plt.xlabel("Item Degree")
# Out:
# Text(0.5, 0, 'Item Degree')

# %%
dc= bipartite.degree_centrality(B, cust_nodes)
sdcc = {}
sdci = {}
for k, v in sorted(dc.items(),reverse=True, key=lambda item: item[1]):
    if k.startswith("Customers"):
        sdcc[k] = v
    else:
        sdci[k] = v

del dc

# %%
list(sdcc.keys())[:10]
# Out:
# ['Customers/14456',
#  'Customers/17920',
#  'Customers/16549',
#  'Customers/16931',
#  'Customers/17238',
#  'Customers/15547',
#  'Customers/18118',
#  'Customers/14546',
#  'Customers/16686',
#  'Customers/16713']

# %%
list(sdci.keys())[:10]
